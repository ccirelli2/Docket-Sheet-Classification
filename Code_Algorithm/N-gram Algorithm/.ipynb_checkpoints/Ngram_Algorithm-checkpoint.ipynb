# %%
# Import Libraries

# %%
import nltk
import pandas as pd
import os
import string
from nltk import corpus

# %%
# Import Personal Modules

# %%
os.chdir('C:\\Users\\Chris.Cirelli\\Desktop\\Python Programming Docs\\GSU\\Sprint Project\\Docket-Sheet-Classification\\Modules')
import Step1_Module as stp1m

# %%
# Import Docket Sheet File w/ Pre-classified time periods

# %%
File = r'C:\Users\Chris.Cirelli\Desktop\Python Programming Docs\GSU\Sprint Project\Docket-Sheet-Classification\Data_Files_applicable to all attempts\DocketSheet Classification_70_02.22.2018.xlsx'
df_docketsheet = pd.read_excel(File)

# %%
# Import Concatenated Text File

# %%
File = open(r'C:\Users\Chris.Cirelli\Desktop\Python Programming Docs\GSU\Sprint Project\Docket-Sheet-Classification\Data_Files_applicable to all attempts\Concatenate_DocketSheet_Text.txt.txt')
Text = File.read()

# %%
# Iterate each docket sheet row, clean text and obtain bigrams

# %%
def get_list_all_bigrams(docketsheet_dataframe):
    '''Purpose:     To generate a list of all bigrams from each of the rows of text in the docketsheet
       Input:       Dataframe of the docketsheet 
       Process:     Iterate over each row, clean and tokenize text, generate bigrams, append bigrams to a list, 
       Output:      Return a set of the bigram list to the user. 
    '''
    # Create a list to catch the bigrams
    List_all_bigrams = []
    
    # Iterate over the panda series 'docket_text'
    for docket_text in df_docketsheet['docket_text']:
        # Ensure that the row is a string and not empty or something else. 
        if isinstance(docket_text, str):
            # Clean and tokenize the text. 
            clean_text = stp1m.clean_andTokenize_text(docket_text)
            # Clean text returns a set, which is not subscriptable, so we need to convert it to a list to generate the
            # bigrams. 
            clean_text_list = list(clean_text)
            append_bigrams = [List_all_bigrams.append((x,y)) for x,y in zip(clean_text_list, clean_text_list[1:])]
    
    # Return to the user a set of the bigrams
    return set(List_all_bigrams)

# %%
Bigram_set = get_list_all_bigrams(df_docketsheet)

# %%
Bigram_set
# Out:
# {('drive', 'behalf'),
#  ('materi', 'declar'),
#  ('interrogatori', 'hayn'),
#  ('servic', 'dismiss'),
#  ('schedul', 'approv'),
#  ('sign', 'februari'),
#  ('final', 'accordingli'),
#  ('farahani', 'admiss'),
#  ('direct', 'district'),
#  ('ad', 'schedul'),
#  ('herebi', 'discoveri'),
#  ('dismiss', 'dazzl'),
#  ('instruct', 'zeester'),
#  ('period', 'magistr'),
#  ('cohen', 'detail'),
#  ('corpor', 'prejudic'),
#  ('manag', 'tilden'),
#  ('judg', 'rivera'),
#  ('melnick', 'interest'),
#  ('date', 'discoveri'),
#  ('employ', 'quash'),
#  ('submit', 'verbal'),
#  ('cost', 'judg'),
#  ('sign', 'substitut'),
#  ('good', 'applic'),
#  ('settlement', 'text'),
#  ('develop', 'circuit'),
#  ('sworn', 'file'),
#  ('bahhur', 'pleas'),
#  ('forth', 'fee'),
#  ('kenia', 'complaint'),
#  ('frap', 'appeal'),
#  ('deposit', 'materi'),
#  ('neddal', 'bahhur'),
#  ('enter', 'duggan'),
#  ('otherwis', 'plaintiff'),
#  ('clerk', 'recommend'),
#  ('vacat', 'complaint'),
#  ('file', 'depart'),
#  ('septemb', 'held'),
#  ('entri', 'remov'),
#  ('counterclaim', 'answer'),
#  ('strike', 'interrogatori'),
#  ('entri', 'sign'),
#  ('product', 'achiev'),
#  ('submit', 'notic'),
#  ('corpor', 'busbi'),
#  ('sign', 'admiss'),
#  ('report', 'thrash'),
#  ('jone', 'herebi'),
#  ('head', 'settlement'),
#  ('submit', 'quash'),
#  ('plaintiff', 'acworth'),
#  ('enter', 'camp'),
#  ('time', 'compel'),
#  ('provid', 'damag'),
#  ('rivera', 'lilleana'),
#  ('drive', 'thompson'),
#  ('thompson', 'herrington'),
#  ('choos', 'stay'),
#  ('process', 'motion'),
#  ('propos', 'claim'),
#  ('judg', 'buttrick'),
#  ('dismiss', 'parmar'),
#  ('return', 'teter'),
#  ('submit', 'document'),
#  ('end', 'held'),
#  ('altisourc', 'retali'),
#  ('except', 'enter'),
#  ('dawkin', 'occup'),
#  ('lift', 'notic'),
#  ('product', 'rabun'),
#  ('associ', 'disclosur'),
#  ('geithner', 'brief'),
#  ('opposit', 'text'),
#  ('propos', 'inform'),
#  ('fact', 'present'),
#  ('summon', 'day'),
#  ('plaintiff', 'system'),
#  ('manag', 'prejudic'),
#  ('applic', 'form'),
#  ('judg', 'appendix'),
#  ('clerk', 'judgment'),
#  ('rule', 'period'),
#  ('case', 'joint'),
#  ('magistr', 'district'),
#  ('offic', 'tilden'),
#  ('complianc', 'clerk'),
#  ('follow', 'telephon'),
#  ('judgment', 'buckholt'),
#  ('first', 'glover'),
#  ('order', 'within'),
#  ('strike', 'file'),
#  ('judgment', 'respons'),
#  ('close', 'extend'),
#  ('conduct', 'hagi'),
#  ('sign', 'implement'),
#  ('grant', 'respons'),
#  ('dekalb', 'emot'),
#  ('foundat', 'attach'),
#  ('district', 'fail'),
#  ('made', 'enter'),
#  ('exhibit', 'dowd'),
#  ('undersign', 'address'),
#  ('presid', 'parti'),
#  ('return', 'dawkin'),
#  ('enter', 'substitut'),
#  ('agreement', 'garber'),
#  ('kelly', 'plaintiff'),
#  ('summari', 'affirm'),
#  ('unoppos', 'krinski'),
#  ('pretrial', 'file'),
#  ('process', 'group'),
#  ('abacu', 'interest'),
#  ('take', 'manhattan'),
#  ('expect', 'steinberg'),
#  ('first', 'motion'),
#  ('notic', 'severin'),
#  ('radford', 'summari'),
#  ('seinberg', 'report'),
#  ('lasai', 'settlement'),
#  ('enter', 'hawk'),
#  ('form', 'motion'),
#  ('judg', 'origin'),
#  ('hoffeck', 'supplement'),
#  ('civil', 'visit'),
#  ('dekalb', 'modifi'),
#  ('brief', 'nydick'),
#  ('entri', 'nonparti'),
#  ('defend', 'part'),
#  ('stipul', 'without'),
#  ('judgment', 'exhibit'),
#  ('seinberg', 'approv'),
#  ('declar', 'manhattan'),
#  ('summari', 'district'),
#  ('batten', 'adopt'),
#  ('katz', 'initi'),
#  ('stay', 'clerk'),
#  ('enter', 'statement'),
#  ('batten', 'rule'),
#  ('anulewicz', 'absenc'),
#  ('abacu', 'enter'),
#  ('proceed', 'full'),
#  ('issu', 'printpack'),
#  ('dekalb', 'execut'),
#  ('stipul', 'sharif'),
#  ('minut', 'kleinman'),
#  ('final', 'judg'),
#  ('consid', 'good'),
#  ('behalf', 'file'),
#  ('order', 'jamal'),
#  ('foundat', 'request'),
#  ('kicklight', 'compani'),
#  ('reflect', 'certif'),
#  ('bahhur', 'higdon'),
#  ('addit', 'statement'),
#  ('district', 'held'),
#  ('supersedea', 'sign'),
#  ('text', 'mover'),
#  ('keebaugh', 'defend'),
#  ('approv', 'telamon'),
#  ('keebaugh', 'propos'),
#  ('develop', 'adopt'),
#  ('stori', 'regard'),
#  ('waterproof', 'form'),
#  ('result', 'make'),
#  ('kushner', 'defend'),
#  ('request', 'pankey'),
#  ('nation', 'blew'),
#  ('solut', 'kresser'),
#  ('return', 'amount'),
#  ('consolid', 'must'),
#  ('deposit', 'mccarthi'),
#  ('materi', 'fact'),
#  ('corp', 'obtain'),
#  ('rule', 'defend'),
#  ('recommend', 'vacat'),
#  ('file', 'manag'),
#  ('direct', 'respons'),
#  ('strike', 'motion'),
#  ('submit', 'magistr'),
#  ('local', 'baverman'),
#  ('defend', 'requir'),
#  ('return', 'amend'),
#  ('windsor', 'enter'),
#  ('argument', 'held'),
#  ('document', 'restaur'),
#  ('associ', 'discoveri'),
#  ('return', 'answer'),
#  ('barn', 'certif'),
#  ('answer', 'insuffici'),
#  ('support', 'summari'),
#  ('order', 'judg'),
#  ('katz', 'continu'),
#  ('newmark', 'first'),
#  ('herrington', 'file'),
#  ('file', 'herrington'),
#  ('rule', 'report'),
#  ('docket', 'brill'),
#  ('seinberg', 'obtain'),
#  ('owen', 'appear'),
#  ('grayson', 'statement'),
#  ('settlement', 'negoti'),
#  ('supplement', 'seek'),
#  ('tape', 'wit'),
#  ('biton', 'locksmith'),
#  ('pertain', 'request'),
#  ('subpoena', 'accur'),
#  ('sign', 'request'),
#  ('cover', 'motion'),
#  ('propos', 'protect'),
#  ('long', 'report'),
#  ('report', 'brill'),
#  ('prucino', 'associ'),
#  ('innov', 'condit'),
#  ('attach', 'march'),
#  ('attach', 'counsel'),
#  ('head', 'pretrial'),
#  ('list', 'deposit'),
#  ('support', 'stone'),
#  ('claim', 'bellow'),
#  ('subpoena', 'issu'),
#  ('minut', 'rule'),
#  ('sign', 'count'),
#  ('thrash', 'enter'),
#  ('locksmith', 'consent'),
#  ('requir', 'plaintiff'),
#  ('proceed', 'grant'),
#  ('serv', 'heard'),
#  ('reopen', 'vine'),
#  ('text', 'addit'),
#  ('dismiss', 'file'),
#  ('enter', 'erickson'),
#  ('occup', 'interest'),
#  ('plan', 'plead'),
#  ('rivera', 'product'),
#  ('attach', 'secret'),
#  ('file', 'wittenmy'),
#  ('order', 'subsequ'),
#  ('confidenti', 'judg'),
#  ('relief', 'sign'),
#  ('enter', 'respons'),
#  ('report', 'enter'),
#  ('tape', 'without'),
#  ('kresser', 'report'),
#  ('docket', 'notic'),
#  ('cost', 'clerk'),
#  ('discoveri', 'foundat'),
#  ('feder', 'visit'),
#  ('hoffeck', 'file'),
#  ('moot', 'enter'),
#  ('employ', 'yarbro'),
#  ('solut', 'dismiss'),
#  ('servic', 'deposit'),
#  ('associ', 'nation'),
#  ('notif', 'notifi'),
#  ('mill', 'regist'),
#  ('reinhardt', 'document'),
#  ('complet', 'time'),
#  ('seal', 'grant'),
#  ('seinberg', 'includ'),
#  ('toth', 'settlement'),
#  ('associ', 'summon'),
#  ('matter', 'consider'),
#  ('pretrial', 'obtain'),
#  ('mortgag', 'summon'),
#  ('motion', 'amend'),
#  ('subpoena', 'commun'),
#  ('discoveri', 'request'),
#  ('usual', 'interest'),
#  ('statement', 'shymeka'),
#  ('telamon', 'stay'),
#  ('clerk', 'report'),
#  ('behalf', 'cunningham'),
#  ('bahhur', 'subpoena'),
#  ('complaint', 'notic'),
#  ('file', 'leav'),
#  ('holub', 'dismiss'),
#  ('instruct', 'counterclaim'),
#  ('discoveri', 'nino'),
#  ('end', 'amend'),
#  ('adopt', 'sign'),
#  ('manag', 'mail'),
#  ('default', 'consult'),
#  ('grant', 'restaur'),
#  ('motion', 'tape'),
#  ('melnick', 'disclosur'),
#  ('teter', 'issu'),
#  ('enter', 'record'),
#  ('opposit', 'bahhur'),
#  ('food', 'discoveri'),
#  ('frye', 'prejudic'),
#  ('agreement', 'record'),
#  ('second', 'document'),
#  ('mail', 'summon'),
#  ('order', 'want'),
#  ('serv', 'submit'),
#  ('pleas', 'ippolito'),
#  ('accur', 'modifi'),
#  ('concern', 'addit'),
#  ('complaint', 'dyke'),
#  ('asid', 'magistr'),
#  ('judgment', 'part'),
#  ('summari', 'file'),
#  ('reflect', 'refer'),
#  ('instruct', 'atla'),
#  ('claim', 'support'),
#  ('repli', 'summari'),
#  ('deni', 'leav'),
#  ('attach', 'file'),
#  ('rule', 'requir'),
#  ('receiv', 'websit'),
#  ('medicin', 'visit'),
#  ('foundat', 'inspect'),
#  ('text', 'head'),
#  ('first', 'robert'),
#  ('mccarthi', 'object'),
#  ('file', 'request'),
#  ('plaintiff', 'wage'),
#  ('pauperi', 'leav'),
#  ('ad', 'demand'),
#  ('settlement', 'propos'),
#  ('dismiss', 'system'),
#  ('inspect', 'devereux'),
#  ('default', 'report'),
#  ('remain', 'product'),
#  ('portfolio', 'reconsider'),
#  ('juli', 'appear'),
#  ('goldemund', 'file'),
#  ('report', 'within'),
#  ('schedul', 'includ'),
#  ('kliesrath', 'notic'),
#  ('evan', 'enter'),
#  ('instruct', 'univers'),
#  ('acworth', 'attorney'),
#  ('process', 'present'),
#  ('addit', 'hear'),
#  ('obtain', 'manhattan'),
#  ('parti', 'docket'),
#  ('reflect', 'initi'),
#  ('document', 'mortgag'),
#  ('enter', 'consent'),
#  ('termin', 'enter'),
#  ('close', 'includ'),
#  ('obtain', 'stay'),
#  ('bridger', 'discoveri'),
#  ('notic', 'januari'),
#  ('object', 'product'),
#  ('answer', 'portfolio'),
#  ('develop', 'appeal'),
#  ('failur', 'enter'),
#  ('complaint', 'motion'),
#  ('katz', 'certif'),
#  ('improv', 'dismiss'),
#  ('reassign', 'assign'),
#  ('file', 'program'),
#  ('instruct', 'end'),
#  ('discoveri', 'keebaugh'),
#  ('wittenmy', 'hight'),
#  ('seal', 'document'),
#  ('second', 'interrogatori'),
#  ('healthcar', 'vice'),
#  ('without', 'agent'),
#  ('pursuant', 'brown'),
#  ('statu', 'court'),
#  ('deposit', 'march'),
#  ('ad', 'buttrick'),
#  ('enter', 'judgment'),
#  ('appel', 'voluntari'),
#  ('district', 'jurisdict'),
#  ('stay', 'defend'),
#  ('restrain', 'written'),
#  ('plan', 'orinda'),
#  ('cowan', 'supplement'),
#  ('text', 'seinberg'),
#  ('chang', 'motion'),
#  ('addit', 'mediat'),
#  ('order', 'resolv'),
#  ('consult', 'evidentiari'),
#  ('motion', 'parti'),
#  ('acworth', 'apart'),
#  ('enter', 'chang'),
#  ('rule', 'kushner'),
#  ('damag', 'enter'),
#  ('parti', 'prejudic'),
#  ('servic', 'jone'),
#  ('pleas', 'clerk'),
#  ('end', 'hanrahan'),
#  ('conduct', 'commenc'),
#  ('associ', 'batten'),
#  ('subpeona', 'provid'),
#  ('certifi', 'sheet'),
#  ('obtain', 'fact'),
#  ('minut', 'joint'),
#  ('end', 'ambul'),
#  ('plaintiff', 'extend'),
#  ('hoffeck', 'joint'),
#  ('report', 'rosenberg'),
#  ('defend', 'lilleana'),
#  ('liquid', 'compens'),
#  ('time', 'leav'),
#  ('submit', 'summari'),
#  ('reinhardt', 'discoveri'),
#  ('coliseum', 'pleas'),
#  ('except', 'deadlin'),
#  ('mediat', 'octob'),
#  ('juli', 'becom'),
#  ('equal', 'opportun'),
#  ('notifi', 'clerk'),
#  ('text', 'northsid'),
#  ('judgement', 'enforc'),
#  ('waiver', 'request'),
#  ('lasai', 'pleas'),
#  ('complaint', 'hawk'),
#  ('compani', 'taken'),
#  ('undersign', 'clerk'),
#  ('traim', 'mowatt'),
#  ('herebi', 'judg'),
#  ('motion', 'opposit'),
#  ('answer', 'file'),
#  ('automat', 'dyke'),
#  ('dismiss', 'also'),
#  ('judgment', 'affidavit'),
#  ('final', 'object'),
#  ('modifi', 'clinica'),
#  ('outcom', 'buttrick'),
#  ('hook', 'first'),
#  ('solut', 'amend'),
#  ('action', 'text'),
#  ('report', 'clerk'),
#  ('proceed', 'notic'),
#  ('servic', 'drewri'),
#  ('issu', 'dekalb'),
#  ('correct', 'contain'),
#  ('johnson', 'problem'),
#  ('consent', 'chang'),
#  ('manhattan', 'continu'),
#  ('reinhardt', 'request'),
#  ('good', 'regard'),
#  ('plan', 'dawkin'),
#  ('blackston', 'food'),
#  ('materi', 'motion'),
#  ('friess', 'affidavit'),
#  ('rivera', 'mccartney'),
#  ('offici', 'approv'),
#  ('enter', 'settlement'),
#  ('judg', 'advis'),
#  ('defend', 'colleg'),
#  ('take', 'disposit'),
#  ('counsel', 'text'),
#  ('sign', 'refer'),
#  ('within', 'enter'),
#  ('bridger', 'execut'),
#  ('defend', 'particip'),
#  ('exhibit', 'notic'),
#  ('gerrilyn', 'punit'),
#  ('district', 'motion'),
#  ('affidavit', 'provision'),
#  ('file', 'media'),
#  ('judg', 'action'),
#  ('summaru', 'report'),
#  ('correct', 'file'),
#  ('nation', 'glianni'),
#  ('time', 'includ'),
#  ('misstat', 'magistr'),
#  ('term', 'motion'),
#  ('file', 'bahhur'),
#  ('statist', 'stori'),
#  ('written', 'stori'),
#  ('hagi', 'defend'),
#  ('brown', 'prucino'),
#  ('settlement', 'approv'),
#  ('judg', 'hagi'),
#  ('radford', 'take'),
#  ('document', 'associ'),
#  ('legar', 'object'),
#  ('jone', 'behalf'),
#  ('sign', 'magistr'),
#  ('improv', 'correct'),
#  ('parti', 'hard'),
#  ('edit', 'motion'),
#  ('indic', 'withdrawn'),
#  ('parti', 'consider'),
#  ('hear', 'product'),
#  ('plaintiff', 'ericson'),
#  ('document', 'origin'),
#  ('seek', 'default'),
#  ('maci', 'answer'),
#  ('amount', 'time'),
#  ('withdraw', 'document'),
#  ('plaintiff', 'correct'),
#  ('brown', 'czekella'),
#  ('garden', 'report'),
#  ('sharman', 'judgment'),
#  ('state', 'northsid'),
#  ('cullen', 'propos'),
#  ('period', 'relat'),
#  ('docket', 'direct'),
#  ('court', 'issu'),
#  ('docket', 'appeal'),
#  ('express', 'attorney'),
#  ('monster', 'dodd'),
#  ('obtain', 'number'),
#  ('author', 'serv'),
#  ('counsel', 'portfolio'),
#  ('document', 'manhattan'),
#  ('motion', 'rabun'),
#  ('supplement', 'goldemund'),
#  ('group', 'corpor'),
#  ('czekalla', 'thing'),
#  ('plaintiff', 'asid'),
#  ('long', 'replac'),
#  ('sign', 'notic'),
#  ('request', 'close'),
#  ('incur', 'attorney'),
#  ('supplement', 'foundat'),
#  ('materi', 'brief'),
#  ('enter', 'second'),
#  ('industri', 'vice'),
#  ('bass', 'enter'),
#  ('extens', 'acworth'),
#  ('coburn', 'behalf'),
#  ('judg', 'scofield'),
#  ('support', 'asid'),
#  ('unabl', 'upon'),
#  ('judg', 'lieu'),
#  ('notat', 'motion'),
#  ('blake', 'frye'),
#  ('nino', 'modifi'),
#  ('pankey', 'doa'),
#  ('grant', 'acworth'),
#  ('minut', 'supplement'),
#  ('direct', 'summari'),
#  ('brief', 'contain'),
#  ('docket', 'execut'),
#  ('amend', 'manag'),
#  ('later', 'motion'),
#  ('motion', 'also'),
#  ('fail', 'court'),
#  ('perform', 'stipul'),
#  ('courtroom', 'requir'),
#  ('instruct', 'plaintiff'),
#  ('plaintiff', 'dodd'),
#  ('stipul', 'enter'),
#  ('technic', 'motion'),
#  ('tower', 'wooten'),
#  ('thirti', 'joint'),
#  ('hawk', 'reconsider'),
#  ('occup', 'issu'),
#  ('brown', 'plead'),
#  ('opposit', 'extend'),
#  ('judg', 'report'),
#  ('supplement', 'declar'),
#  ('pretrial', 'addit'),
#  ('titl', 'enter'),
#  ('discoveri', 'also'),
#  ('object', 'report'),
#  ('issu', 'enter'),
#  ('system', 'disclosur'),
#  ('northern', 'place'),
#  ('taken', 'phillip'),
#  ('without', 'complaint'),
#  ('pankey', 'product'),
#  ('order', 'court'),
#  ('extens', 'achiev'),
#  ('day', 'specif'),
#  ('interest', 'report'),
#  ('issu', 'product'),
#  ('grant', 'event'),
#  ('minut', 'hawk'),
#  ('discoveri', 'within'),
#  ('servic', 'enter'),
#  ('object', 'defend'),
#  ('read', 'affect'),
#  ('reduc', 'section'),
#  ('group', 'compani'),
#  ('busbi', 'coliseum'),
#  ('buckholt', 'taken'),
#  ('hayn', 'neddal'),
#  ('fitzpatrick', 'document'),
#  ('seal', 'katz'),
#  ('plaintiff', 'baverman'),
#  ('extend', 'defend'),
#  ('object', 'neddal'),
#  ('metro', 'enter'),
#  ('grant', 'attorney'),
#  ('employ', 'reduc'),
#  ('deposit', 'subpoena'),
#  ('plaintiff', 'electron'),
#  ('judg', 'appeal'),
#  ('magistr', 'notat'),
#  ('correct', 'counsel'),
#  ('extens', 'duffey'),
#  ('plaintiff', 'afford'),
#  ('hight', 'disclosur'),
#  ('enter', 'resourc'),
#  ('moot', 'defend'),
#  ('number', 'consent'),
#  ('enter', 'notat'),
#  ('board', 'summon'),
#  ('garden', 'attach'),
#  ('ad', 'fuch'),
#  ('recommend', 'submit'),
#  ('contain', 'judg'),
#  ('sinkfield', 'stone'),
#  ('direct', 'close'),
#  ('file', 'sign'),
#  ('document', 'kennington'),
#  ('attach', 'bahhur'),
#  ('clerk', 'thrash'),
#  ('pursuant', 'appel'),
#  ('sign', 'administr'),
#  ('serv', 'answer'),
#  ('vineyard', 'adjust'),
#  ('court', 'extend'),
#  ('repres', 'notic'),
#  ('krinski', 'certif'),
#  ('plan', 'schreiber'),
#  ('file', 'motion'),
#  ('confer', 'court'),
#  ('group', 'joint'),
#  ('motion', 'extend'),
#  ('product', 'northsid'),
#  ('request', 'conduct'),
#  ('brief', 'plaintiff'),
#  ('fuch', 'second'),
#  ('associ', 'corpor'),
#  ('thereaft', 'sign'),
#  ('johnson', 'appear'),
#  ('discoveri', 'post'),
#  ('court', 'adopt'),
#  ('mediat', 'stay'),
#  ('northsid', 'execut'),
#  ('healthcar', 'issu'),
#  ('robert', 'request'),
#  ('fuch', 'certifi'),
#  ('enter', 'repres'),
#  ('kliesrath', 'respons'),
#  ('discoveri', 'extend'),
#  ('mail', 'grant'),
#  ('acknowledg', 'readi'),
#  ('parti', 'time'),
#  ('devereux', 'foust'),
#  ('vice', 'brissett'),
#  ('interest', 'northsid'),
#  ('servic', 'zeester'),
#  ('entri', 'period'),
#  ('file', 'medicin'),
#  ('technolog', 'document'),
#  ('file', 'subject'),
#  ('pannel', 'final'),
#  ('second', 'extens'),
#  ('rivera', 'report'),
#  ('pleas', 'hagi'),
#  ('bridger', 'modifi'),
#  ('error', 'notif'),
#  ('dekalb', 'product'),
#  ('hanrahan', 'amend'),
#  ('evidentiari', 'execut'),
#  ('recommend', 'claim'),
#  ('seal', 'reach'),
#  ('prdp', 'day'),
#  ('judg', 'expens'),
#  ('attach', 'judgment'),
#  ('case', 'orinda'),
#  ('memorandm', 'dismiss'),
#  ('action', 'wolf'),
#  ('cambridg', 'certif'),
#  ('manag', 'brissett'),
#  ('januari', 'summari'),
#  ('unboundari', 'disclosur'),
#  ('young', 'attorney'),
#  ('system', 'vice'),
#  ('administr', 'settl'),
#  ('document', 'list'),
#  ('foust', 'product'),
#  ('second', 'brown'),
#  ('attach', 'initi'),
#  ('default', 'upon'),
#  ('order', 'prucino'),
#  ('errata', 'origin'),
#  ('east', 'rule'),
#  ('either', 'matter'),
#  ('baverman', 'approv'),
#  ('issu', 'medicin'),
#  ('period', 'consent'),
#  ('enter', 'wooten'),
#  ('negoti', 'tape'),
#  ('gaylor', 'approv'),
#  ('wolf', 'approv'),
#  ('servic', 'hook'),
#  ('enter', 'fuch'),
#  ('dodd', 'defend'),
#  ('discoveri', 'errata'),
#  ('amic', 'revis'),
#  ('fair', 'protect'),
#  ('shionogi', 'end'),
#  ('plead', 'text'),
#  ('extens', 'certif'),
#  ('select', 'docket'),
#  ('system', 'execut'),
#  ('accordingli', 'state'),
#  ('clerk', 'receipt'),
#  ('proceed', 'magistr'),
#  ('submit', 'shoob'),
#  ('servic', 'thompson'),
#  ('judg', 'termin'),
#  ('edit', 'attorney'),
#  ('statement', 'certif'),
#  ('industri', 'mail'),
#  ('improv', 'motion'),
#  ('servic', 'bill'),
#  ('dismiss', 'well'),
#  ('attach', 'system'),
#  ('instruct', 'proceed'),
#  ('cover', 'unboundari'),
#  ('request', 'octob'),
#  ('discoveri', 'hayn'),
#  ('deadlin', 'stori'),
#  ('reief', 'motion'),
#  ('month', 'assign'),
#  ('judg', 'promptli'),
#  ('discoveri', 'busbi'),
#  ('altisourc', 'address'),
#  ('properti', 'behalf'),
#  ('owen', 'defend'),
#  ('abacu', 'product'),
#  ('inflict', 'partial'),
#  ('without', 'februari'),
#  ('exhibit', 'plaintiff'),
#  ('design', 'enter'),
#  ('applic', 'gaylor'),
#  ('consent', 'grant'),
#  ('shall', 'enter'),
#  ('order', 'correct'),
#  ('enter', 'motion'),
#  ('vann', 'approv'),
#  ('oper', 'remain'),
#  ('time', 'parti'),
#  ('lieu', 'system'),
#  ('make', 'style'),
#  ('date', 'pannel'),
#  ('hook', 'interest'),
#  ('district', 'day'),
#  ('discoveri', 'shall'),
#  ('wooten', 'summon'),
#  ('long', 'rule'),
#  ('magistr', 'altern'),
#  ('attach', 'parti'),
#  ('seal', 'enter'),
#  ('associ', 'issu'),
#  ('websit', 'dai'),
#  ('state', 'except'),
#  ('eagl', 'text'),
#  ('direct', 'purpos'),
#  ('wittenmy', 'claim'),
#  ('direct', 'jone'),
#  ('carn', 'motion'),
#  ('joint', 'food'),
#  ('engag', 'retali'),
#  ('absenc', 'appli'),
#  ('attach', 'lieu'),
#  ('adopt', 'approv'),
#  ('offer', 'guidanc'),
#  ('propos', 'thrash'),
#  ('request', 'modifi'),
#  ('mail', 'extens'),
#  ('submit', 'grant'),
#  ('court', 'hear'),
#  ('text', 'abacu'),
#  ('northsid', 'disclosur'),
#  ('johnson', 'lift'),
#  ('protect', 'standard'),
#  ('kelly', 'number'),
#  ('brown', 'leav'),
#  ('seek', 'report'),
#  ('servic', 'continu'),
#  ('extens', 'moncrief'),
#  ('refil', 'corpor'),
#  ('declar', 'opposit'),
#  ('deadlin', 'direct'),
#  ('conclus', 'take'),
#  ('file', 'brief'),
#  ('limit', 'schedul'),
#  ('stipul', 'respect'),
#  ('counsel', 'court'),
#  ('return', 'process'),
#  ('consent', 'sinkfield'),
#  ('notic', 'mixon'),
#  ('full', 'question'),
#  ('subject', 'advis'),
#  ('retali', 'interfer'),
#  ('seek', 'defend'),
#  ('enter', 'school'),
#  ('caudl', 'approv'),
#  ('applic', 'dwyer'),
#  ('order', 'appel'),
#  ('resubmit', 'court'),
#  ('joint', 'correct'),
#  ('court', 'mediat'),
#  ('enter', 'sharif'),
#  ('young', 'broker'),
#  ('clerk', 'attempt'),
#  ('judg', 'expir'),
#  ('depart', 'owen'),
#  ('decemb', 'person'),
#  ('forma', 'sheet'),
#  ('enter', 'extens'),
#  ('administr', 'direct'),
#  ('restaur', 'amend'),
#  ('amend', 'disclosur'),
#  ('amend', 'brief'),
#  ('direct', 'manhattan'),
#  ('extend', 'enter'),
#  ('end', 'complaint'),
#  ('instruct', 'district'),
#  ('jone', 'dismiss'),
#  ('vine', 'file'),
#  ('settlement', 'ad'),
#  ('failur', 'dekalb'),
#  ('exhibit', 'grayson'),
#  ('file', 'supersedea'),
#  ('incorpor', 'order'),
#  ('stone', 'request'),
#  ('discoveri', 'baverman'),
#  ('fact', 'northsid'),
#  ('mccarthi', 'request'),
#  ('dazzl', 'issu'),
#  ('process', 'return'),
#  ('enter', 'incorrectli'),
#  ('discoveri', 'entri'),
#  ('modifi', 'johnson'),
#  ('lasai', 'interest'),
#  ('tax', 'plaintiff'),
#  ('enter', 'taken'),
#  ('defend', 'januari'),
#  ('fourth', 'enter'),
#  ('move', 'enter'),
#  ('associ', 'electron'),
#  ('indic', 'interest'),
#  ('garden', 'defend'),
#  ('use', 'keebaugh'),
#  ('demand', 'redocket'),
#  ('caduceu', 'instruct'),
#  ('expect', 'order'),
#  ('warn', 'defend'),
#  ('answer', 'partial'),
#  ('certifi', 'copi'),
#  ('univers', 'declar'),
#  ('adjust', 'joint'),
#  ('submiss', 'retali'),
#  ('notifi', 'stay'),
#  ('paon', 'enter'),
#  ('document', 'dismiss'),
#  ('develop', 'johnson'),
#  ('memorandum', 'judgment'),
#  ('person', 'deadlin'),
#  ('agreement', 'judg'),
#  ('proceed', 'pacer'),
#  ('entri', 'affidavit'),
#  ('brearley', 'propos'),
#  ('sheryl', 'dismiss'),
#  ('minut', 'judg'),
#  ('plaintiff', 'melnick'),
#  ('insuffici', 'report'),
#  ('interrogatori', 'ippolito'),
#  ('hudlow', 'corpor'),
#  ('approv', 'friday'),
#  ('servic', 'applic'),
#  ('judg', 'disclosur'),
#  ('paper', 'close'),
#  ('rule', 'evan'),
#  ('unoppos', 'respons'),
#  ('counsel', 'coot'),
#  ('koenig', 'telamon'),
#  ('extend', 'respond'),
#  ('judg', 'respond'),
#  ('pleas', 'discrimin'),
#  ('default', 'clerk'),
#  ('attach', 'fact'),
#  ('thirti', 'time'),
#  ('adopt', 'report'),
#  ('end', 'schreiber'),
#  ('remov', 'extens'),
#  ('notif', 'default'),
#  ('close', 'tent'),
#  ('judg', 'modifi'),
#  ('geithner', 'attach'),
#  ('reconsider', 'court'),
#  ('affect', 'extens'),
#  ('motion', 'resolut'),
#  ('judgment', 'perform'),
#  ('sign', 'march'),
#  ('septemb', 'judg'),
#  ('file', 'consult'),
#  ('enter', 'identifi'),
#  ('claim', 'labor'),
#  ('line', 'held'),
#  ('carecloud', 'electron'),
#  ('sign', 'failur'),
#  ('mattress', 'mortgag'),
#  ('injunct', 'thompson'),
#  ('mover', 'summari'),
#  ('bellow', 'exhibit'),
#  ('civil', 'johnson'),
#  ('czekalla', 'plaintiff'),
#  ('waiver', 'reinhardt'),
#  ('plaintiff', 'lieu'),
#  ('handwritten', 'entri'),
#  ('enter', 'serv'),
#  ('mercantil', 'product'),
#  ('affidavit', 'claim'),
#  ('summari', 'portfolio'),
#  ('interrogatori', 'request'),
#  ('copi', 'appeal'),
#  ('resolv', 'disput'),
#  ('roja', 'respons'),
#  ('exhibit', 'updat'),
#  ('caus', 'confer'),
#  ('includ', 'mattress'),
#  ('answer', 'first'),
#  ('issu', 'telamon'),
#  ('parti', 'dismiss'),
#  ('extend', 'stay'),
#  ('filer', 'group'),
#  ('entri', 'submit'),
#  ('winkler', 'follow'),
#  ('appear', 'mail'),
#  ('http', 'without'),
#  ('admiss', 'plaintiff'),
#  ('conven', 'clerk'),
#  ('action', 'cost'),
#  ('obtain', 'mcelroy'),
#  ('servic', 'end'),
#  ('pannel', 'motion'),
#  ('nation', 'electron'),
#  ('dimiss', 'memorandm'),
#  ('excess', 'court'),
#  ('matter', 'blank'),
#  ('drewri', 'discoveri'),
#  ('goldemund', 'interrogatori'),
#  ('duti', 'rabun'),
#  ('enter', 'restaur'),
#  ('confer', 'back'),
#  ('also', 'moot'),
#  ('stipul', 'univers'),
#  ('entri', 'extens'),
#  ('side', 'retain'),
#  ('notic', 'atla'),
#  ('consumm', 'date'),
#  ('declar', 'motion'),
#  ('appear', 'neddal'),
#  ('melnick', 'defend'),
#  ('incorrectli', 'edit'),
#  ('extens', 'pankey'),
#  ('judg', 'discoveri'),
#  ('necessari', 'withdraw'),
#  ('second', 'materi'),
#  ('neddal', 'object'),
#  ('pleas', 'depart'),
#  ('dawkin', 'behalf'),
#  ('attach', 'part'),
#  ('bill', 'amount'),
#  ('molden', 'transcript'),
#  ('enter', 'krinski'),
#  ('discoveri', 'garden'),
#  ('arbi', 'plaintiff'),
#  ('lilleana', 'visit'),
#  ('motion', 'clarif'),
#  ('plaintiff', 'altern'),
#  ('leav', 'novemb'),
#  ('text', 'prejudic'),
#  ('assert', 'prejudic'),
#  ('preliminari', 'motion'),
#  ('file', 'dodd'),
#  ('frye', 'counti'),
#  ('initi', 'product'),
#  ('opinion', 'interim'),
#  ('answer', 'group'),
#  ('judg', 'name'),
#  ('report', 'printpack'),
#  ('district', 'servic'),
#  ('addit', 'text'),
#  ('amend', 'affirm'),
#  ('close', 'modifi'),
#  ('sign', 'forma'),
#  ('magistr', 'garber'),
#  ('take', 'reflect'),
#  ('stay', 'protect'),
#  ('behalf', 'product'),
#  ('hayn', 'discoveri'),
#  ('amircani', 'maha'),
#  ('certif', 'note'),
#  ('hayn', 'judg'),
#  ('otherwis', 'statement'),
#  ('shall', 'accordingli'),
#  ('plaintiff', 'tender'),
#  ('brief', 'insuffici'),
#  ('mover', 'enter'),
#  ('brief', 'manag'),
#  ...}

# %%
# Create a Frequency Distribution of Bigrams For Entire Text

# %%
def get_Freq_Dist_Ngrams(Text, Ngram_selection):
    
    Dict_Ngram_freq_dist = {}

    Clean_tokenized_text = list(stp1m.clean_andTokenize_text_return_list(Text))
    
    if Ngram_selection == 'Bigrams':
        Text_bigrams = (((x,y)) for x,y in zip(Clean_tokenized_text, 
                                               Clean_tokenized_text[1:]))
        for x in Text_bigrams:
            Dict_Ngram_freq_dist[x] = Dict_Ngram_freq_dist.get(x, 0) + 1
            
    elif Ngram_selection == 'Trigrams':
        Text_trigrams = (((x,y,z)) for x,y,z in zip(Clean_tokenized_text, 
                                                    Clean_tokenized_text[1:], 
                                                    Clean_tokenized_text[2:]))
        for x in Text_trigrams:
            Dict_Ngram_freq_dist[x] = Dict_Ngram_freq_dist.get(x, 0) + 1

    elif Ngram_selection == 'Quadgrams':
        Text_quadgrams = (((w,x,y,z)) for w,x,y,z in zip(Clean_tokenized_text, 
                                                    Clean_tokenized_text[1:], 
                                                    Clean_tokenized_text[2:], 
                                                    Clean_tokenized_text[3:]))
        for x in Text_quadgrams:
            Dict_Ngram_freq_dist[x] = Dict_Ngram_freq_dist.get(x, 0) + 1
    
    return Dict_Ngram_freq_dist

# %%
Bigram_freq_dist = get_Freq_Dist_Ngrams(Text, 'Bigrams')
Trigram_freq_dist = get_Freq_Dist_Ngrams(Text, 'Trigrams')
Quad_freq_dist = get_Freq_Dist_Ngrams(Text, 'Quadgrams')

# %%
df_bigram = pd.DataFrame(Bigram_freq_dist, index = [len(Bigram_freq_dist)]).transpose().reset_index()
df_trigram = pd.DataFrame(Trigram_freq_dist, index = [len(Trigram_freq_dist)]).transpose().reset_index()
df_quadgram = pd.DataFrame(Quad_freq_dist, index = [len(Quad_freq_dist)]).transpose().reset_index()

# %%
os.chdir(r'C:\Users\Chris.Cirelli\Desktop\Python Programming Docs\GSU\Sprint Project\Docket-Sheet-Classification\Results_Files_Bigrams')
stp1m.write_to_excel(df_bigram, 'Docketsheet_Bigram_Freq_Dist')
stp1m.write_to_excel(df_trigram, 'Docketsheet_Trigram_Freq_Dist')
stp1m.write_to_excel(df_quadgram, 'Docketsheet_Quadgram_Freq_Dist')
