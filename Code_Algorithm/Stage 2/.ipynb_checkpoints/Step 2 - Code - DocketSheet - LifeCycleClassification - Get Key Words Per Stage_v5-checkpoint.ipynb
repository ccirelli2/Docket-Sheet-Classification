# %%
# IMPORT LIBRARIES

# %%
import pandas as pd
import os

# %%
# IMPORT MODULES

# %%
os.chdir('C:\\Users\\Chris.Cirelli\\Desktop\\Python Programming Docs\\GSU\\Sprint Project\\Docket-Sheet-Classification\\Modules')

# Module to Calculate Measurements of Central Tendancy
import Step2_Module_Calculations_Central_Tendancy as stp2_cal_CT
# Module to Calculate Top Words
import Step2_Module_Get_Top_Words as stp2_get_words

# %%
# IMPORT FREQUENCY DISTRIBUTION EXCEL FILE AS DATAFRAME

# %%
df_freqDist = pd.read_excel(r'C:\Users\Chris.Cirelli\Desktop\Python Programming Docs\GSU\Sprint Project\Docket-Sheet-Classification\Result_Files_Key_Word_Attempt_2\DocketSheet_wordSet_Freq_Dist_v4_03.11.2018.xlsx')

# %%
def drop_measures_CT(dataframe_with_measures_CT, methodology_CT):
    '''
    The purpose of this function is to drop the columns that are being appended directly to the df_rename_col dataframe. 
    '''
    # Create a dataframe to capture the new df without these column headings. 
    df_final = ''
    
    if methodology_CT == 'CalculationIII_Correlation_Coefficient':
        df_final = dataframe_with_measures_CT.drop(['AVG', 'STDV', 'COCOEF'], axis = 1)
     
    else:
        df_final = dataframe_with_measures_CT.drop(['AVG', 'STDV'], axis = 1)
    
    return df_final

# %%
# RUN FUNCTION TO GET TOP WORDS

# %%
def get_top_words_toggle_methodology(dataframe_freq_distribution, methodology_CT, methodology_top_words):
    '''
    FUNCTION_I:     get_Measurements_CentralTendancy
        Input       a.) The dataframe containing the word frequency distributions. b.) One of the below cal methodologies. sza
        Options     'CalculationI_homebrew_STDV', 
                    'CalculationII_AVG_not_zero', 
                    'CalculationIII_Correlation_Coefficient'
    
    FUNCTION_II:    get_top_words
        Input       a.) The dataframe containing the word frequency distribution, b.) One of the below methodologies, 
                    c.) The stage, which is defined within this namespace. 
        Options     'Top15_highest_STDV_homebrew', 
                    'Top15_highest_COCOEF', 
                    'Top5_highest_STDV_lowest_AVG', 
                    'Top5_highest_STDV_AVG_below_20prct', 
                    'Top5_lowest_STDV_highest_AVG', 
                    'Top5_lowest_COCOEF_highest_AVG'
    
    
    '''

    df_rename_cols = dataframe_freq_distribution.rename(index = str, columns = {
                                                                'Life Cycle Stage: 1.0': 1 , 'Life Cycle Stage: 2.0': 2, 
                                                                'Life Cycle Stage: 3.0': 3, 'Life Cycle Stage: 4.0':  4,
                                                                'Life Cycle Stage: 5.0': 5, 'Life Cycle Stage: 6.0':  6,
                                                                'Life Cycle Stage: 7.0': 7, 'Life Cycle Stage: 8.0':  8,
                                                                'Life Cycle Stage: 9.0': 9, 'Life Cycle Stage: 10.0': 10,
                                                                'Life Cycle Stage: 11.0': 11})
    
    # Create a new dataframe to capture the top words and set the index to 0-14
    df_top_words = pd.DataFrame({}, index = [x for x in range(0,15)])
    
    # Reset df_rename_cols to just the columns 0-11
    if len(df_rename_cols.columns) > 11:
        df_rename_cols = df_rename_cols.iloc[:, 0:11]
    
    # Keep Count of Life Cycle Stage
    Stage = ''

    # Iterative Function to Rotate Our Columns in Ascending Order. 
    for num in range(1,12):
        
        # Loop Starts at Life Cycle 1.  Set Condition that when it reaches 11 it stops. 
        if df_rename_cols.columns[0] != 101:
                       
            # Stage
            Stage = df_rename_cols.columns[0]
            
            # Calculate Measures of Central Tendancy
            df_with_measures_of_CT = stp2_cal_CT.get_Measurements_CentralTendancy(df_rename_cols, methodology_CT)
            
            # Get Top Words
            Top_words_all_calc = stp2_get_words.get_top_words(df_rename_cols, methodology_top_words, Stage)
            
            
            # Define the column name
            Col_name = str(Top_words_all_calc.columns[0])
            
            # Capture all rows and just the target column of the dataframe. 
            Top_words_target_stage = Top_words_all_calc.iloc[:,0]

            # Append to our dataframe that will be returned to the user the top 5 words for each Life Cycle Stage.  
            df_top_words[Col_name] = Top_words_target_stage
            
            # Reset df_rename_cols to just the columns 0-11
            if len(df_rename_cols.columns) > 11:
                df_rename_cols = df_rename_cols.iloc[:, 0:11]
            
            # Rename the first column to = num + 100.  Num = Original Col1 at each iteration.
            df_col_increased_by100 = df_rename_cols.rename(index = str, columns = {num: num+100})
            
            # With the first column renamed, sort ascending.  This will move the first column to the end. 
            df_rotate = df_col_increased_by100.sort_index(axis = 1, ascending = True)
            df_rename_cols = df_rotate
    
    return df_top_words

# %%
df_with_measures_CT = get_top_words_toggle_methodology(df_freqDist, 
                                                       'CalculationIII_Correlation_Coefficient', 
                                                       'Top5_lowest_COCOEF_highest_AVG')

# %%
df_with_measures_CT
# Out:
#    Life Cycle Stage: 1 Life Cycle Stage: 2 Life Cycle Stage: 3  \
# 0             thompson              defens               first
# 1                hight              second               repli
# 2              mcelroy             product               metro
# 3             brittani             timothi              liabil
# 4               bellow              modifi               offer
# 5                  NaN                 NaN                 NaN
# 6                  NaN                 NaN                 NaN
# 7                  NaN                 NaN                 NaN
# 8                  NaN                 NaN                 NaN
# 9                  NaN                 NaN                 NaN
# 10                 NaN                 NaN                 NaN
# 11                 NaN                 NaN                 NaN
# 12                 NaN                 NaN                 NaN
# 13                 NaN                 NaN                 NaN
# 14                 NaN                 NaN                 NaN
#
#    Life Cycle Stage: 4 Life Cycle Stage: 5 Life Cycle Stage: 6  \
# 0                court               notic              submit
# 1                 rule                 day                text
# 2              partial               charl                judg
# 3                order              modifi              second
# 4               direct              liabil             consent
# 5                  NaN                 NaN                 NaN
# 6                  NaN                 NaN                 NaN
# 7                  NaN                 NaN                 NaN
# 8                  NaN                 NaN                 NaN
# 9                  NaN                 NaN                 NaN
# 10                 NaN                 NaN                 NaN
# 11                 NaN                 NaN                 NaN
# 12                 NaN                 NaN                 NaN
# 13                 NaN                 NaN                 NaN
# 14                 NaN                 NaN                 NaN
#
#    Life Cycle Stage: 7 Life Cycle Stage: 8 Life Cycle Stage: 9  \
# 0              respons              attach              liabil
# 1               liabil              within              assign
# 2                 rudi                cost           plainitff
# 3            plainitff               refer             misstat
# 4              misstat             compani              affili
# 5                  NaN                 NaN                 NaN
# 6                  NaN                 NaN                 NaN
# 7                  NaN                 NaN                 NaN
# 8                  NaN                 NaN                 NaN
# 9                  NaN                 NaN                 NaN
# 10                 NaN                 NaN                 NaN
# 11                 NaN                 NaN                 NaN
# 12                 NaN                 NaN                 NaN
# 13                 NaN                 NaN                 NaN
# 14                 NaN                 NaN                 NaN
#
#    Life Cycle Stage: 10 Life Cycle Stage: 11
# 0                 vacat             baverman
# 1                  rule                 judg
# 2                 emerg               liabil
# 3                assign               tamica
# 4             plainitff            plainitff
# 5                   NaN                  NaN
# 6                   NaN                  NaN
# 7                   NaN                  NaN
# 8                   NaN                  NaN
# 9                   NaN                  NaN
# 10                  NaN                  NaN
# 11                  NaN                  NaN
# 12                  NaN                  NaN
# 13                  NaN                  NaN
# 14                  NaN                  NaN

# %%
# WRITE RESULTS TO A SINGLE EXCEL SHEET

# %%
os.chdir(r'C:\Users\Chris.Cirelli\Desktop\Python Programming Docs\GSU\Sprint Project\Docket-Sheet-Classification\Result_Files_Key_Word_Attempt_2')

# %%
writer = pd.ExcelWriter('Top5_Key_words_03.11.2018_v3.xlsx')

Top_5_words_highestCV_lowestAVG.to_excel(writer,
                                                 'Sheet1', 
                                                columns = Top_5_words_highestCV_lowestAVG.columns)
Top_5_words_highestCV_medium_AVG.to_excel(writer,
                                                       'Sheet1', 
                                                       startrow = 6, 
                                                       header = '')
Top_5_words_Lowest_CV.to_excel(writer, 
                                                       'Sheet1', 
                                                       startrow = 11, 
                                                       header = '')
writer.save()

# %%
# READ BACK IN THE FILE JUST CREATED

# %%
df = pd.read_excel(r'C:\Users\Chris.Cirelli\Desktop\Python Programming Docs\GSU\Sprint Project\Docket-Sheet-Classification\Result_Files_Key_Word_Attempt_2\Top5_Key_words_03.11.2018_v3.xlsx')

# %%
df
# Out:
#   Life Cycle Stage: 1 Life Cycle Stage: 2 Life Cycle Stage: 3  \
# 0                 NaN              answer                 NaN
# 1             proceed                 end             support
# 2             consent                 NaN               brief
# 3                form                 NaN               claim
# 4               sheet                 NaN              failur
# 0             receipt                 NaN            prejudic
# 1            pretrial            pretrial                 NaN
# 2            instruct            instruct                 NaN
# 3             magistr              obtain                 NaN
# 4              obtain               pleas                 NaN
# 0               pleas                http                 NaN
# 1              motion               cover               visit
# 2              termin                juri              websit
# 3              consid              demand               cover
# 4                read              termin              termin
# 5                good                read                good
#
#   Life Cycle Stage: 4 Life Cycle Stage: 5 Life Cycle Stage: 6  \
# 0                 NaN                 NaN                 NaN
# 1               clerk           discoveri           statement
# 2               entri              certif                fact
# 3            pursuant             deposit             respons
# 4              approv              servic              materi
# 0            prejudic           plaintiff             exhibit
# 1                sign                 NaN             summari
# 2           plaintiff                 NaN            judgment
# 3              defend                 NaN              defend
# 4                 NaN                 NaN                time
# 0                 NaN                 NaN               notic
# 1               cover               cover               cover
# 2              appeal              termin              termin
# 3              termin                read                good
# 4               shown                good                read
# 5                caus               shown              consid
#
#   Life Cycle Stage: 7 Life Cycle Stage: 8 Life Cycle Stage: 9  \
# 0                 NaN                 NaN                 NaN
# 1           recommend          settlement               joint
# 2              report              approv              extens
# 3               final           agreement              adjust
# 4            district               entri              affect
# 0                sign               parti                sign
# 1           plaintiff                sign                 NaN
# 2               clerk            prejudic                 NaN
# 3              defend                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
# 0                 NaN                 NaN                 NaN
# 1              termin               cover               cover
# 2              appeal              termin              termin
# 3               cover                read              websit
# 4               shown                good               visit
# 5                read               shown              appeal
#
#   Life Cycle Stage: 10 Life Cycle Stage: 11
# 0                  NaN               termin
# 1               appeal                  NaN
# 2                 hawk                  NaN
# 3              circuit                  NaN
# 4                 usca                  NaN
# 0                notic                civil
# 1               number                  NaN
# 2                amend                  NaN
# 3                  NaN                  NaN
# 4                  NaN                  NaN
# 0                  NaN                  NaN
# 1                cover                cover
# 2                sheet               motion
# 3               termin                 read
# 4               consid                 good
# 5                 good                shown

# %%
# CREATE A LIST OF A SINGLE SET OF THE KEY WORDS

# %%
def get_key_word_set(key_word_dataframe):
    key_word_list = []
    for x in key_word_dataframe:
        word_list = list(key_word_dataframe[x])
        [key_word_list.append(x) for x in word_list]
    
    key_word_set = list(set(key_word_list))
    
    df = pd.DataFrame(key_word_set)

    return df

# %%
key_word_set = get_key_word_set(df)

# %%
st1.write_to_excel(key_word_set, 'Key_word_set_4_algorithm_input_03.11.2018_v3')
