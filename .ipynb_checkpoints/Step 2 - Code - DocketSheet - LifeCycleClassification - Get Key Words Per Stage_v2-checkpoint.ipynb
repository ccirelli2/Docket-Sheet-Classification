# %%
# IMPORT LIBRARIES

# %%
import pandas as pd
import Step1_Module as st1
import Step2_Module as st2

# %%
# IMPORT FREQUENCY DISTRIBUTION EXCEL FILE AS DATAFRAME

# %%
df_freqDist = pd.read_excel(r'C:\Users\Chris.Cirelli\Desktop\Python Programming Docs\GSU\Sprint Project\Docket-Sheet-Classification\DocketSheet_wordSet_Freq_Dist_v2.xlsx', index_col = 'Index')

# %%
len(df_freqDist.iloc[0,1:])
# Out:
# 10

# %%
# GET WORDS WITH HIGHEST STDV FOR EACH LIFE CYCLE STAGE

# %%
def get_Top_5_words_highest_STDVfreq_lowest_AVG(df_freqDist):
    '''The purpose of this function is to return a dataframe for each Life Cycle Stage with the Top 5 words with the highest standard deviation.
    
    Input      = Dataframe with the frequency with which each word appears in the 11 life cycle stages. 
    Operations = 1.) Rename columns to numerical representations of each stage. 
                 2.) Create a function that rotates the columns one by one in ascending order.
                 3.) For each iteration of this rotation write a function that generates a dataframe with two columns, the Life Cycle Stage w/ names & the concurrent 
                 STDV vs the other time periods. 
                 4.) Combine the columns into a single dataframe from each time period. = 50 columns or structure into rows, 5 columns, 22 rows. 
    Output     = A dataframe with the top 5 words whose avg is between .001 and .02 and whose STDV_freq is the highest.   
    '''
    
    # Rename Columns - Integer representation of each Stage (1-11).
    
    df_rename_cols = df_freqDist.rename(index = str, columns = {'Life Cycle Stage: 1.0': 1 , 'Life Cycle Stage: 2.0': 2, 
                                                                'Life Cycle Stage: 3.0': 3, 'Life Cycle Stage: 4.0':  4,
                                                                'Life Cycle Stage: 5.0': 5, 'Life Cycle Stage: 6.0':  6,
                                                                'Life Cycle Stage: 7.0': 7, 'Life Cycle Stage: 8.0':  8,
                                                                'Life Cycle Stage: 9.0': 9, 'Life Cycle Stage: 10.0': 10,
                                                                'Life Cycle Stage: 11.0': 11})
    

    # Create a Dataframe to house the top 5 words for each Life Cycle Stage. 
    df_final_top5 = pd.DataFrame({}, index = [1,2,3,4,5])

    
    # Keep Count of Life Cycle Stage
    Stage = ''

    # Iterative Function to Rotate Our Columns in Ascending Order. 
    for num in range(1,12):
        
        # Loop Starts at Life Cycle 1.  Set Condition that when it reaches 11 it stops. 
        if df_rename_cols.columns[0] != 101:
                       
            # Stage
            Stage = df_rename_cols.columns[0]
            
            # Function to obtain the AVG and STDV for the top 5 words.
            df_AVG_STDV = st2.get_AVG_STDV_Target_Stage(df_rename_cols)
            
            # Error in Code.  df_rename_cols is directly being appended AVG, STDV.  Not clear why.  Needed to recreate the object here
            # and drop the AVG and STDV columns for the code to run. 
            df_rename_cols = df_rename_cols.drop(['AVG', 'STDV', 'STDV_freq'], axis = 1)
    
            # Get Dataframe of Top 5 words with highest STDV
            df_top5_AVG_STDV = st2.get_df_top5words_STDV(df_AVG_STDV, Stage)
        
            # Append to our Dataframe the top 5 words for each Life Cycle Stage.  
            df_final_top5[df_top5_AVG_STDV.columns[0]] = df_top5_AVG_STDV.iloc[:,0]
                    
            # Rename the first column to = num + 100.  Num = Original Col1 at each iteration.
            df_rename_cols = df_rename_cols.rename(index = str, columns = {num: num+100})
            
            # With the first column renamed, sort ascending.  This will move the first column to the end. 
            df_rename_cols = df_rename_cols.sort_index(axis = 1, ascending = True)
    
    # Return to the user the list of dataframes for each of the 11 Life Cycle Stages. 
    return df_final_top5

# %%
Top_5_words_highest_STDVfreq_lowest_AVG = get_Top_5_words_highest_STDVfreq_lowest_AVG(df_freqDist)
# Out:
# C:\Users\Chris.Cirelli\Desktop\Python Programming Docs\GSU\Sprint Project\Docket-Sheet-Classification\Step2_Module.py:21: RuntimeWarning: divide by zero encountered in double_scalars
#   STDV = row[1] / AVG
# C:\Users\Chris.Cirelli\Desktop\Python Programming Docs\GSU\Sprint Project\Docket-Sheet-Classification\Step2_Module.py:21: RuntimeWarning: invalid value encountered in double_scalars
#   STDV = row[1] / AVG

# %%
Top_5_words_highest_STDVfreq_lowest_AVG
# Out:
#   Life Cycle Stage: 1 Life Cycle Stage: 2 Life Cycle Stage: 3  \
# 1             proceed              answer             default
# 2                juri              corpor              daniel
# 3              demand              associ               brown
# 4              includ            northsid             partial
# 5                issu               drive            northsid
#
#   Life Cycle Stage: 4 Life Cycle Stage: 5 Life Cycle Stage: 6  \
# 1                cost             request               repli
# 2            attorney               first                eddi
# 3                 fee            document             michael
# 4              action              jennif              declar
# 5             without                wayn                gari
#
#   Life Cycle Stage: 7 Life Cycle Stage: 8 Life Cycle Stage: 9  \
# 1               adopt               close               leigh
# 2               vacat               linda              bahhur
# 3             william                stay              neddal
# 4                lewi              associ             deadlin
# 5               delor                bear              martin
#
#   Life Cycle Stage: 10 Life Cycle Stage: 11
# 1               appeal                linda
# 2                 hawk                 cole
# 3                 lewi                susan
# 4                delor                drive
# 5               docket               randal

# %%
st1.write_to_excel(Top_5_words_highest_STDVfreq_lowest_AVG, 'Top_5_words_highest_STDVfreq_lowest_AVG')

# %%
# GET WORDS WITH HIGHEST STDV FOR EACH LIFE CYCLE STAGE W/ AVG > 2%.

# %%
def get_Top_5_words_highest_STDVfreq_AVG_greater_two_percent(df_freqDist):

    '''
    Output     = A dataframe with the top 5 words whose avg is between .001 and .02 and whose STDV_freq is the highest.   
    '''
    
    # Rename Columns - Integer representation of each Stage (1-11).
    
    df_rename_cols = df_freqDist.rename(index = str, columns = {'Life Cycle Stage: 1.0': 1 , 'Life Cycle Stage: 2.0': 2, 
                                                                'Life Cycle Stage: 3.0': 3, 'Life Cycle Stage: 4.0':  4,
                                                                'Life Cycle Stage: 5.0': 5, 'Life Cycle Stage: 6.0':  6,
                                                                'Life Cycle Stage: 7.0': 7, 'Life Cycle Stage: 8.0':  8,
                                                                'Life Cycle Stage: 9.0': 9, 'Life Cycle Stage: 10.0': 10,
                                                                'Life Cycle Stage: 11.0': 11})
    

    # Create a Dataframe to house the top 5 words for each Life Cycle Stage. 
    df_final_top5 = pd.DataFrame({}, index = [1,2,3,4,5])

    
    # Keep Count of Life Cycle Stage
    Stage = ''

    # Iterative Function to Rotate Our Columns in Ascending Order. 
    for num in range(1,12):
        
        # Loop Starts at Life Cycle 1.  Set Condition that when it reaches 11 it stops. 
        if df_rename_cols.columns[0] != 101:
                       
            # Stage
            Stage = df_rename_cols.columns[0]
            
            # Function to obtain the AVG and STDV for the top 5 words.
            df_AVG_STDV = st2.get_AVG_STDV_Target_Stage(df_rename_cols)
            
            # Error in Code.  df_rename_cols is directly being appended AVG, STDV.  Not clear why.  Needed to recreate the object here
            # and drop the AVG and STDV columns for the code to run. 
            df_rename_cols = df_rename_cols.drop(['AVG', 'STDV', 'STDV_freq'], axis = 1)
    
            # Get Dataframe of Top 5 words with highest STDV
            df_top5_AVG_STDV = st2.get_df_top5words_AVG_greater_two_percent(df_AVG_STDV, Stage)
        
            # Append to our Dataframe the top 5 words for each Life Cycle Stage.  
            df_final_top5[df_top5_AVG_STDV.columns[0]] = df_top5_AVG_STDV.iloc[:,0]
                    
            # Rename the first column to = num + 100.  Num = Original Col1 at each iteration.
            df_rename_cols = df_rename_cols.rename(index = str, columns = {num: num+100})
            
            # With the first column renamed, sort ascending.  This will move the first column to the end. 
            df_rename_cols = df_rename_cols.sort_index(axis = 1, ascending = True)
    
    # Return to the user the list of dataframes for each of the 11 Life Cycle Stages. 
    return df_final_top5

# %%
Top5_highest_STDVfreq_AVG_greater_two_percent = get_Top_5_words_highest_STDVfreq_AVG_greater_two_percent(df_freqDist)
# Out:
# C:\Users\Chris.Cirelli\Desktop\Python Programming Docs\GSU\Sprint Project\Docket-Sheet-Classification\Step2_Module.py:21: RuntimeWarning: divide by zero encountered in double_scalars
#   STDV = row[1] / AVG
# C:\Users\Chris.Cirelli\Desktop\Python Programming Docs\GSU\Sprint Project\Docket-Sheet-Classification\Step2_Module.py:21: RuntimeWarning: invalid value encountered in double_scalars
#   STDV = row[1] / AVG

# %%
Top5_highest_STDVfreq_AVG_greater_two_percent
# Out:
#   Life Cycle Stage: 1 Life Cycle Stage: 2 Life Cycle Stage: 3  \
# 1                form               visit               brief
# 2             consent              websit             support
# 3              websit            instruct               claim
# 4               visit            pretrial              stipul
# 5            instruct                http            prejudic
#
#   Life Cycle Stage: 4 Life Cycle Stage: 5 Life Cycle Stage: 6  \
# 1            prejudic           discoveri             summari
# 2            pursuant              certif             respons
# 3               entri              servic               brief
# 4               clerk             univers             exhibit
# 5              stipul              report             support
#
#   Life Cycle Stage: 7 Life Cycle Stage: 8 Life Cycle Stage: 9  \
# 1           recommend              approv               joint
# 2               final              stipul              extens
# 3              report               entri                time
# 4            district            prejudic              herebi
# 5                deni            pursuant               shall
#
#   Life Cycle Stage: 10 Life Cycle Stage: 11
# 1                danni                civil
# 2                notic                 case
# 3               number               walker
# 4                amend             baverman
# 5                 leav                 alan

# %%
st1.write_to_excel(Top5_highest_STDVfreq_AVG_greater_two_percent,'Top5_highest_STDVfreq_AVG_greater_two_percent')

# %%
def get_Top_5_words_Target_below_2percent_highest_AVG(df_freqDist):

    '''
    Output     =   
    '''
    
    # Rename Columns - Integer representation of each Stage (1-11).
    
    df_rename_cols = df_freqDist.rename(index = str, columns = {'Life Cycle Stage: 1.0': 1 , 'Life Cycle Stage: 2.0': 2, 
                                                                'Life Cycle Stage: 3.0': 3, 'Life Cycle Stage: 4.0':  4,
                                                                'Life Cycle Stage: 5.0': 5, 'Life Cycle Stage: 6.0':  6,
                                                                'Life Cycle Stage: 7.0': 7, 'Life Cycle Stage: 8.0':  8,
                                                                'Life Cycle Stage: 9.0': 9, 'Life Cycle Stage: 10.0': 10,
                                                                'Life Cycle Stage: 11.0': 11})
    

    # Create a Dataframe to house the top 5 words for each Life Cycle Stage. 
    df_final_top5 = pd.DataFrame({}, index = [1,2,3,4,5])

    
    # Keep Count of Life Cycle Stage
    Stage = ''

    # Iterative Function to Rotate Our Columns in Ascending Order. 
    for num in range(1,12):
        
        # Loop Starts at Life Cycle 1.  Set Condition that when it reaches 11 it stops. 
        if df_rename_cols.columns[0] != 101:
                       
            # Stage
            Stage = df_rename_cols.columns[0]
            
            # Function to obtain the AVG and STDV for the top 5 words.
            df_AVG_STDV = st2.get_AVG_STDV_Target_Stage(df_rename_cols)
            
            # Error in Code.  df_rename_cols is directly being appended AVG, STDV.  Not clear why.  Needed to recreate the object here
            # and drop the AVG and STDV columns for the code to run. 
            df_rename_cols = df_rename_cols.drop(['AVG', 'STDV', 'STDV_freq'], axis = 1)
    
            # Get Dataframe of Top 5 words with highest STDV
            df_top5_AVG_STDV = st2.get_df_top5words_Target_nearZero_highest_AVG(df_AVG_STDV, Stage)
        
            # Append to our Dataframe the top 5 words for each Life Cycle Stage.  
            df_final_top5[df_top5_AVG_STDV.columns[0]] = df_top5_AVG_STDV.iloc[:,0]
                    
            # Rename the first column to = num + 100.  Num = Original Col1 at each iteration.
            df_rename_cols = df_rename_cols.rename(index = str, columns = {num: num+100})
            
            # With the first column renamed, sort ascending.  This will move the first column to the end. 
            df_rename_cols = df_rename_cols.sort_index(axis = 1, ascending = True)
    
    # Return to the user the list of dataframes for each of the 11 Life Cycle Stages. 
    return df_final_top5

# %%
Top_5_words_Target_below_2percent_highest_AVG = get_Top_5_words_Target_below_2percent_highest_AVG(df_freqDist)
# Out:
# C:\Users\Chris.Cirelli\Desktop\Python Programming Docs\GSU\Sprint Project\Docket-Sheet-Classification\Step2_Module.py:21: RuntimeWarning: divide by zero encountered in double_scalars
#   STDV = row[1] / AVG
# C:\Users\Chris.Cirelli\Desktop\Python Programming Docs\GSU\Sprint Project\Docket-Sheet-Classification\Step2_Module.py:21: RuntimeWarning: invalid value encountered in double_scalars
#   STDV = row[1] / AVG

# %%
Top_5_words_Target_below_2percent_highest_AVG
# Out:
#   Life Cycle Stage: 1 Life Cycle Stage: 2 Life Cycle Stage: 3  \
# 1             dismiss                time              attach
# 2            judgment               civil                time
# 3                case              extens              extens
# 4             summari               joint               civil
# 5               joint               grant               joint
#
#   Life Cycle Stage: 4 Life Cycle Stage: 5 Life Cycle Stage: 6  \
# 1           complaint             dismiss               civil
# 2                case           complaint               joint
# 3             dismiss                case              extens
# 4               civil               civil               notic
# 5                http               joint            pretrial
#
#   Life Cycle Stage: 7 Life Cycle Stage: 8 Life Cycle Stage: 9  \
# 1           complaint           complaint              attach
# 2                time             dismiss           complaint
# 3              extens             magistr               pleas
# 4               civil            judgment                http
# 5                http                case              obtain
#
#   Life Cycle Stage: 10 Life Cycle Stage: 11
# 1               motion              dismiss
# 2                 file             judgment
# 3                order                 time
# 4               attach               extens
# 5              dismiss              summari

# %%
st1.write_to_excel(Top_5_words_Target_below_2percent_highest_AVG, 'Top_5_words_Target_below_2percent_highest_AVG')
